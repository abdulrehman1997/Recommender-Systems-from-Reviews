# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import normalize

# %%
useritem = pd.read_csv('/Users/abdulrehman/Desktop/usml/data/AMAZON_FASHION_posonly_user_itemset.csv')
useritem = useritem.fillna(0)
useritem = useritem.replace(4, 1)
useritem = useritem.replace(5, 1)
_ = useritem.iloc[:,0].values
data = useritem.iloc[:,1:].values
data_scaled = normalize(data)

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
dendogram = sch.dendrogram(sch.linkage(data_scaled,method='single', metric="cosine"))

# %%
dendogram = sch.dendrogram(sch.linkage(data_scaled,method='complete', metric="cosine"))

# %%
dendogram = sch.dendrogram(sch.linkage(data_scaled,method='average', metric="cosine"))

# %%
dendogram = sch.dendrogram(sch.linkage(data_scaled,method='weighted', metric="cosine"))
